# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Car_sales.csv')

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        152 non-null    object
#  1   Model               152 non-null    object
#  2   Sales_in_thousands  152 non-null    float64
#  3   Vehicle_type        152 non-null    object
#  4   Price_in_thousands  152 non-null    float64
#  5   Engine_size         152 non-null    float64
#  6   Horsepower          152 non-null    float64
#  7   Wheelbase           152 non-null    float64
#  8   Width               152 non-null    float64
#  9   Length              152 non-null    float64
#  10  Curb_weight         152 non-null    float64
#  11  Fuel_capacity       152 non-null    float64
#  12  Fuel_efficiency     152 non-null    float64
#  13  Latest_Launch       152 non-null    datetime64[ns]
#  14  Power_perf_factor   152 non-null    float64
# ...

# %% [markdown]
# # Insights

# %%
clean_df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0        Acura  Integra              16.919    Passenger               21.50
# 1        Acura       TL              39.384    Passenger               28.40
# 3        Acura       RL               8.588    Passenger               42.00
# 4         Audi       A4              20.397    Passenger               23.99
# 5         Audi       A6              18.780    Passenger               33.95
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
# 5          2.8       200.0      108.7   76.1   192.0        3.561
#
#    Fuel_capacity  Fuel_efficiency Latest_Launch  Power_perf_factor
# ...

# %%
# Out:
# Text(0, 0.5, 'Sales ($\\times 10^3$)')

# %%
# Out:
# <Axes: xlabel='Price_in_thousands', ylabel='Horsepower'>

# %%
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
clean_df.head(10)
# Out:
#    Manufacturer    Model  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0         Acura  Integra              16.919    Passenger              21.500
# 1         Acura       TL              39.384    Passenger              28.400
# 3         Acura       RL               8.588    Passenger              42.000
# 4          Audi       A4              20.397    Passenger              23.990
# 5          Audi       A6              18.780    Passenger              33.950
# 6          Audi       A8               1.380    Passenger              62.000
# 7           BMW     323i              19.747    Passenger              26.990
# 8           BMW     328i               9.231    Passenger              33.400
# 9           BMW     528i              17.527    Passenger              38.900
# 10        Buick  Century              91.561    Passenger              21.975
#
#     Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# ...

# %%
revenue_by_origin
# Out:
# origin
# Asia           45559.053559
# Europe         15937.184170
# N. America    114874.844981
# Name: Revenue, dtype: float64

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        152 non-null    object
#  1   Model               152 non-null    object
#  2   Sales_in_thousands  152 non-null    float64
#  3   Vehicle_type        152 non-null    object
#  4   Price_in_thousands  152 non-null    float64
#  5   Engine_size         152 non-null    float64
#  6   Horsepower          152 non-null    float64
#  7   Wheelbase           152 non-null    float64
#  8   Width               152 non-null    float64
#  9   Length              152 non-null    float64
#  10  Curb_weight         152 non-null    float64
#  11  Fuel_capacity       152 non-null    float64
#  12  Fuel_efficiency     152 non-null    float64
#  13  Latest_Launch       152 non-null    datetime64[ns]
#  14  Power_perf_factor   152 non-null    float64
# ...
